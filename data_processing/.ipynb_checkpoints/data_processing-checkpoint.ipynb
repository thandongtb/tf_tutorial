# %%
import pandas as pd
import warnings

warnings.filterwarnings('ignore')
# Out:
# /home/vibloteam/tensorflow_tutorial/lib/python3.5/importlib/_bootstrap.py:222: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)
# /home/vibloteam/tensorflow_tutorial/lib/python3.5/importlib/_bootstrap.py:222: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)

# %%
# Load data

import os

housing = pd.read_csv('housing.csv')

# %%
housing.head(3)
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                41.0        880.0           129.0
# 1    -122.22     37.86                21.0       7099.0          1106.0
# 2    -122.24     37.85                52.0       1467.0           190.0
#
#    population  households  median_income  median_house_value ocean_proximity
# 0       322.0       126.0         8.3252            452600.0        NEAR BAY
# 1      2401.0      1138.0         8.3014            358500.0        NEAR BAY
# 2       496.0       177.0         7.2574            352100.0        NEAR BAY

# %%
housing.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20640 entries, 0 to 20639
# Data columns (total 10 columns):
# longitude             20640 non-null float64
# latitude              20640 non-null float64
# housing_median_age    20640 non-null float64
# total_rooms           20640 non-null float64
# total_bedrooms        20433 non-null float64
# population            20640 non-null float64
# households            20640 non-null float64
# median_income         20640 non-null float64
# median_house_value    20640 non-null float64
# ocean_proximity       20640 non-null object
# dtypes: float64(9), object(1)
# memory usage: 1.6+ MB

# %% [markdown]
# ## Data understanding
#
# There are 20,640 instances in the dataset, which means that it is fairly small by
# Machine Learning standards, but it’s perfect to get started. Notice that the total_bed
# rooms attribute has only 20,433 non-null values, meaning that 207 districts are miss‐
# ing this feature. We will need to take care of this later.

# %%
housing['ocean_proximity'].value_counts()
# Out:
# <1H OCEAN     9136
# INLAND        6551
# NEAR OCEAN    2658
# NEAR BAY      2290
# ISLAND           5
# Name: ocean_proximity, dtype: int64

# %%
housing.describe()
# Out:
#           longitude      latitude  housing_median_age   total_rooms  \
# count  20640.000000  20640.000000        20640.000000  20640.000000
# mean    -119.569704     35.631861           28.639486   2635.763081
# std        2.003532      2.135952           12.585558   2181.615252
# min     -124.350000     32.540000            1.000000      2.000000
# 25%     -121.800000     33.930000           18.000000   1447.750000
# 50%     -118.490000     34.260000           29.000000   2127.000000
# 75%     -118.010000     37.710000           37.000000   3148.000000
# max     -114.310000     41.950000           52.000000  39320.000000
#
#        total_bedrooms    population    households  median_income  \
# count    20433.000000  20640.000000  20640.000000   20640.000000
# mean       537.870553   1425.476744    499.539680       3.870671
# std        421.385070   1132.462122    382.329753       1.899822
# min          1.000000      3.000000      1.000000       0.499900
# ...

# %%
# Another quick way is visualize the data with graph

# %matplotlib inline 

import matplotlib.pyplot as plt

housing.hist(bins=50, figsize=(20, 15))

plt.show()

# %% [markdown]
# # Some problems in  histogram
#
# * Different scale of attributes
# * Tail very heavy => transformation to bell shape
# * Data is limited

# %%
housing.plot(kind='scatter', x='longitude', y='latitude', alpha=0.1)

# %%
# Find the relate between housing price and location

housing.plot(kind='scatter', x='longitude', y='latitude', alpha=0.5, 
            s=housing['population'] / 50, label='population', figsize=(12, 8),
            c='median_house_value', cmap=plt.get_cmap('jet'), colorbar=True)

# %% [markdown]
# # Map of california
#
# ![](https://www.google.com.vn/maps/vt/data=ILHFXe3jioD0HIi5Q_vMk7fEl4SNBFTkdoIwrlaX36l4m0BgMp2xJ9s9uER_ZQwjwvJzGsK5wOrvFd6-nxgbgeKi3jAlNDkSOoHLlmaLLoRyqWN76HdEAZdoiqrPNP1tlaVFl5Zw6eQrixmFnx9fAshe8MrPbUpCUDxmzkSeQ35_d3WTCmdekTu-JrcDw3Bl-pARLNx4wmddm097Xih0qfnzequqSfUW8r2Jsw0PGQJTmQ)

# %% [markdown]
# # Compute the correlation matrix between attributes

# %%
corr_matrix = housing.corr()

# %%
corr_matrix['median_house_value'].sort_values()
# Out:
# latitude             -0.144160
# longitude            -0.045967
# population           -0.024650
# total_bedrooms        0.049686
# households            0.065843
# housing_median_age    0.105623
# total_rooms           0.134153
# median_income         0.688075
# median_house_value    1.000000
# Name: median_house_value, dtype: float64

# %% [markdown]
# # Cleaning data

# %%
median = housing["total_bedrooms"].median()

housing["total_bedrooms"].fillna(median, inplace=True)

# %% [markdown]
# # Attributes combination

# %%
housing['room_per_household'] = housing['total_rooms'] / housing['households']

housing['bedroom_per_household'] = housing['total_bedrooms'] / housing['households']

housing['population_per_household'] = housing['population'] / housing['households']

# %%
housing.head(3)
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                41.0        880.0           129.0
# 1    -122.22     37.86                21.0       7099.0          1106.0
# 2    -122.24     37.85                52.0       1467.0           190.0
#
#    population  households  median_income  median_house_value ocean_proximity  \
# 0       322.0       126.0         8.3252            452600.0        NEAR BAY
# 1      2401.0      1138.0         8.3014            358500.0        NEAR BAY
# 2       496.0       177.0         7.2574            352100.0        NEAR BAY
#
#    room_per_household  bedroom_per_household  population_per_household
# 0            6.984127               1.023810                  2.555556
# 1            6.238137               0.971880                  2.109842
# 2            8.288136               1.073446                  2.802260

# %%
corr_matrix = housing.corr()

corr_matrix['median_house_value'].sort_values()
# Out:
# latitude                   -0.144160
# longitude                  -0.045967
# bedroom_per_household      -0.045637
# population                 -0.024650
# population_per_household   -0.023737
# total_bedrooms              0.049457
# households                  0.065843
# housing_median_age          0.105623
# total_rooms                 0.134153
# room_per_household          0.151948
# median_income               0.688075
# median_house_value          1.000000
# Name: median_house_value, dtype: float64

# %% [markdown]
# # Handing the text to categorical attributes

# %%
# Pandas get dumies method

housing_dummies = pd.get_dummies(housing, prefix=['ocean_proximity'])
housing_dummies.head(3)
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                41.0        880.0           129.0
# 1    -122.22     37.86                21.0       7099.0          1106.0
# 2    -122.24     37.85                52.0       1467.0           190.0
#
#    population  households  median_income  median_house_value  \
# 0       322.0       126.0         8.3252            452600.0
# 1      2401.0      1138.0         8.3014            358500.0
# 2       496.0       177.0         7.2574            352100.0
#
#    room_per_household  bedroom_per_household  population_per_household  \
# 0            6.984127               1.023810                  2.555556
# 1            6.238137               0.971880                  2.109842
# 2            8.288136               1.073446                  2.802260
#
#    ocean_proximity_<1H OCEAN  ocean_proximity_INLAND  ocean_proximity_ISLAND  \
# ...

# %% [markdown]
# # Feature scaling
#
#
# * **Normalization** also call with min-max scaling to put the number value in range. We do this by subtract‐
# ing the min value and dividing by the max minus the min
# * **Standardization** first it subtracts the mean value (so standardized
# values always have a zero mean), and then it divides by the variance so that the result‐
# ing distribution has unit variance.

# %%
import numpy as np

tmp = np.array([1, 2, 3, 4, 4, 5, 67, 2, 21, 54])

# %%
from sklearn.preprocessing import MinMaxScaler

min_max_scaler = MinMaxScaler()

min_max_scaler.fit(tmp.reshape(-1, 1))

min_max_scaler.transform([[1, 3, 2]])
# Out:
# array([[0.        , 0.03030303, 0.01515152]])

# %%
from sklearn.preprocessing import StandardScaler

std_scaler = StandardScaler()

std_scaler.fit(tmp.reshape(-1, 1))

std_scaler.transform([[1, 3, 2]])
# Out:
# array([[-0.66685186, -0.57968168, -0.62326677]])

# %%
(2 - tmp.mean()) / (tmp.std())
# Out:
# -0.6232667690465246

# %%
# Transform data

scaler = MinMaxScaler()

housing_features = housing_dummies.drop('median_house_value', axis=1)

X_data = scaler.fit_transform(housing_features)

# %%
y_data = np.array(housing_dummies['median_house_value'])

y_data = y_data.reshape(len(y_data), 1)

# %% [markdown]
# ## Note
#
# Unlike min-max scaling, standardization does not
# bound values to a specific range, which may be a problem for some algorithms (e.g.,
# neural networks often expect an input value ranging from 0 to 1). However, standard‐
# ization is much less affected by outliers

# %%
# Train test split 

from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X_data, y_data, test_size=0.2, random_state=42)

# %%
X_train.shape
# Out:
# (16512, 16)

# %%
y_test.shape
# Out:
# (4128, 1)

# %%
X_train[0]
# Out:
# array([0.72908367, 0.01806589, 0.62745098, 0.0794547 , 0.09714463,
#        0.06437961, 0.10228581, 0.19032151, 0.02957193, 0.02607762,
#        0.00241382, 0.        , 0.        , 0.        , 0.        ,
#        1.        ])

# %%
# Placeholder for pass data
import tensorflow as tf

n_dim = 16

X = tf.placeholder(tf.float32, [None, n_dim])

Y = tf.placeholder(tf.float32, [None, 1])

# %%
# Trainable weights

W = tf.Variable(tf.random_uniform([n_dim, 1]), dtype=tf.float32)

b = tf.Variable(tf.zeros(1, dtype = tf.float32))

# %%
pred = tf.add(tf.matmul(X, W), b)

mse_loss = tf.reduce_mean(tf.square(Y - pred))

loss = tf.sqrt(mse_loss)

learning_rate = 300

optimizer = tf.train.GradientDescentOptimizer(learning_rate=learning_rate).minimize(loss)

# %%
init = tf.global_variables_initializer()

# %%
sess = tf.Session()

# %%
# Training

sess.run(init)

# %%
epochs = 50000
for epoch in range(epochs):
    
    sess.run(optimizer, feed_dict={X: X_train, Y: y_train})
    
    train_loss = sess.run(loss, feed_dict={X : X_train, Y: y_train})
    test_loss = sess.run(loss, feed_dict={X : X_test, Y: y_test})
 
    if epoch % 1000 == 0:
        print("Epoch {} Train loss {} Test loss = {}".format(epoch, train_loss, test_loss))
        
print("Training finished")
# Out:
# Epoch 0 Train loss 72220.59375 Test loss = 72959.1640625
# Epoch 1000 Train loss 72198.171875 Test loss = 72944.8046875
# Epoch 2000 Train loss 72177.109375 Test loss = 72931.3828125
# Epoch 3000 Train loss 72157.328125 Test loss = 72918.8203125
# Epoch 4000 Train loss 72138.625 Test loss = 72906.9609375
# Epoch 5000 Train loss 72120.9296875 Test loss = 72895.75
# Epoch 6000 Train loss 72104.125 Test loss = 72885.09375
# Epoch 7000 Train loss 72088.140625 Test loss = 72874.9296875
# Epoch 8000 Train loss 72072.875 Test loss = 72865.1875
# Epoch 9000 Train loss 72058.2265625 Test loss = 72855.8046875
# Epoch 10000 Train loss 72044.203125 Test loss = 72846.7265625
# Epoch 11000 Train loss 72030.6953125 Test loss = 72837.953125
# Epoch 12000 Train loss 72017.640625 Test loss = 72829.4140625
# Epoch 13000 Train loss 72005.03125 Test loss = 72821.0859375
# Epoch 14000 Train loss 71992.8203125 Test loss = 72812.921875
# Epoch 15000 Train loss 71980.9296875 Test loss = 72804.9140625
# ...

# %%
from sklearn.linear_model import LinearRegression
lin_reg = LinearRegression()
lin_reg.fit(X_train, y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
lin_reg.coef_.reshape(n_dim, 1)
# Out:
# array([[-2.70693986e+05],
#        [-2.44534080e+05],
#        [ 5.62013069e+04],
#        [-8.50003354e+04],
#        [ 2.68575970e+05],
#        [-1.40061095e+06],
#        [ 5.89065111e+05],
#        [ 5.95492333e+05],
#        [-6.95096236e+05],
#        [ 1.29887583e+06],
#        [ 7.69851100e+04],
#        [-4.60879311e+17],
#        [-4.60879311e+17],
#        [-4.60879311e+17],
#        [-4.60879311e+17],
#        [-4.60879311e+17]])

# %%
y_pred = lin_reg.predict(X_test)

# %%
y_model_pred = sess.run(pred, feed_dict={X : X_test, Y: y_test})

# %%
from sklearn.metrics import mean_squared_error

def rmse_evaluate(y_pred, y_test):
    lin_mse = mean_squared_error(y_pred, y_test)

    return np.sqrt(lin_mse)

# %%
rmse_evaluate(y_pred, y_test)
# Out:
# 73415.76002591773

# %%
rmse_evaluate(y_model_pred, y_test)
# Out:
# 72554.56128762024
